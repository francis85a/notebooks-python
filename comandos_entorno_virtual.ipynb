# %% [markdown]
# ## COMANDOS PARA CREAR ENTORNO VIRTUAL

# %% [markdown]
# - sudo apt install python3-pip (instalar pip)

# %% [markdown]
# - sudo apt install python3.12-venv (instalar venv)

# %% [markdown]
# - python3 -m venv .venv (crear entorno virtual)

# %% [markdown]
# - source venv/bin/activate (activar entorno)

# %% [markdown]
# - pip3 install ipykernel (instalar kernel)

# %% [markdown]
# ### Instalar pytest

# %% [markdown]
# - pip3 install -U pytest

# %% [markdown]
# ### Crear documento requirements.txt

# %% [markdown]
# - pip3 freeze > requirements.txt
